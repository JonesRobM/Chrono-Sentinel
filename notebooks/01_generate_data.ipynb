# %% [markdown]
# # 01 - Data Loading and Exploration
#
# This notebook demonstrates loading NAB (Numenta Anomaly Benchmark) data and exploring its structure.
#
# ## Contents
# 1. Loading NAB datasets
# 2. Visualising time-series with anomaly labels
# 3. Creating sliding windows
# 4. Examining class balance

# %%
import sys

sys.path.insert(0, "..")

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from threatsim.data import (
    DEFAULT_DATASETS,
    DEFAULT_TEST_SERIES,
    DEFAULT_TRAIN_SERIES,
    DEFAULT_VAL_SERIES,
    create_windows,
    get_dataloaders,
    load_nab_data,
    nab_anomaly_mask,
    normalise_windows,
    prepare_grouped_splits,
)

plt.style.use("seaborn-v0_8-whitegrid")

# %% [markdown]
# ## 1. Loading NAB Data
#
# The NAB dataset contains real-world time-series with labelled anomalies. Let's load one of the default datasets.

# %%
# Load the machine temperature dataset
dataset_name = "realKnownCause/machine_temperature_system_failure.csv"
df, anomaly_timestamps = load_nab_data(dataset_name)

print(f"Dataset: {dataset_name}")
print(f"Shape: {df.shape}")
print(f"Anomaly timestamps: {anomaly_timestamps}")
print("\nFirst few rows:")
df.head()
# Out:
# Dataset: realKnownCause/machine_temperature_system_failure.csv
# Shape: (22695, 2)
# Anomaly timestamps: ['2013-12-11 06:00:00', '2013-12-16 17:25:00', '2014-01-28 13:55:00', '2014-02-08 14:30:00']
#
# First few rows:
#             timestamp      value
# 0 2013-12-02 21:15:00  73.967322
# 1 2013-12-02 21:20:00  74.935882
# 2 2013-12-02 21:25:00  76.124162
# 3 2013-12-02 21:30:00  78.140707
# 4 2013-12-02 21:35:00  79.329836

# %%
# Basic statistics
print("Value statistics:")
df["value"].describe()
# Out:
# Value statistics:
# count    22695.000000
# mean        85.926498
# std         13.746912
# min          2.084721
# 25%         83.080078
# 50%         89.408246
# 75%         94.016252
# max        108.510543
# Name: value, dtype: float64

# %% [markdown]
# ## 2. Visualising Time-Series with Anomalies
#
# Let's plot the time-series and highlight the anomaly regions.

# %%
# Create anomaly mask
anomaly_mask = nab_anomaly_mask(df, anomaly_timestamps)

print(f"Total points: {len(df)}")
print(f"Anomaly points: {anomaly_mask.sum()} ({100 * anomaly_mask.mean():.2f}%)")
# Out:
# Total points: 22695
# Anomaly points: 452 (1.99%)

# %%
# Plot full time-series
fig, ax = plt.subplots(figsize=(14, 5))

ax.plot(df["timestamp"], df["value"], "b-", linewidth=0.5, alpha=0.8, label="Value")

# Highlight anomaly regions
anomaly_indices = np.where(anomaly_mask == 1)[0]
if len(anomaly_indices) > 0:
    ax.scatter(
        df["timestamp"].iloc[anomaly_indices],
        df["value"].iloc[anomaly_indices],
        c="red",
        s=5,
        alpha=0.5,
        label="Anomaly Region",
    )

ax.set_xlabel("Timestamp")
ax.set_ylabel("Temperature")
ax.set_title("Machine Temperature System Failure Dataset")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Creating Sliding Windows
#
# We convert the time-series into overlapping windows for the transformer model.

# %%
# Create windows
values = df["value"].values.astype(np.float32)
windows, window_labels = create_windows(
    values, anomaly_mask, window_size=50, step_size=10
)

print(f"Number of windows: {len(windows)}")
print(f"Window shape: {windows.shape}")
print(f"Anomalous windows: {window_labels.sum()} ({100 * window_labels.mean():.2f}%)")
# Out:
# Number of windows: 2265
# Window shape: (2265, 50)
# Anomalous windows: 65 (2.87%)

# %%
# Visualise some example windows
fig, axes = plt.subplots(2, 4, figsize=(14, 6))

# Normal windows
normal_indices = np.where(window_labels == 0)[0]
for i, ax in enumerate(axes[0]):
    idx = normal_indices[i * 100]  # Sample from different parts
    ax.plot(windows[idx], "b-")
    ax.set_title(f"Normal (idx={idx})")
    ax.set_xlabel("Time step")

# Anomalous windows
anomaly_indices = np.where(window_labels == 1)[0]
for i, ax in enumerate(axes[1]):
    if i < len(anomaly_indices):
        idx = anomaly_indices[min(i * 10, len(anomaly_indices) - 1)]
        ax.plot(windows[idx], "r-")
        ax.set_title(f"Anomaly (idx={idx})")
    ax.set_xlabel("Time step")

plt.suptitle("Example Windows: Normal (top) vs Anomalous (bottom)")
plt.tight_layout()
plt.show()

# %%
# Normalise windows
normalised = normalise_windows(windows)

print(f"Before normalisation - Mean: {windows.mean():.2f}, Std: {windows.std():.2f}")
print(
    f"After normalisation - Mean: {normalised.mean():.4f}, Std: {normalised.std():.4f}"
)
# Out:
# Before normalisation - Mean: 85.92, Std: 13.75
# After normalisation - Mean: -0.0000, Std: 1.0000

# %% [markdown]
# ## 4. Creating DataLoaders
#
# Let's use the convenience function to create train/val/test DataLoaders.

# %%
# DataLoaders. Splits are grouped by series: train, validation and test draw
# from disjoint sets of NAB series, so this measures generalisation to an
# unseen asset. Returns a fitted FeatureScaler alongside the loaders because
# the serving path has to apply exactly the same feature transform.
train_loader, val_loader, test_loader, pos_weight, scaler = get_dataloaders(
    window_size=50,
    step_size=10,
    batch_size=32,
)

print(
    f"Train series: {len(DEFAULT_TRAIN_SERIES)}, windows: {len(train_loader.dataset)}"
)
print(f"Val   series: {len(DEFAULT_VAL_SERIES)}, windows: {len(val_loader.dataset)}")
print(f"Test  series: {len(DEFAULT_TEST_SERIES)}, windows: {len(test_loader.dataset)}")
print(f"Positive-class weight: {pos_weight.item():.2f}")
# Out:
# Train series: 7, windows: 4588
# Val   series: 2, windows: 1427
# Test  series: 3, windows: 3063
# Positive-class weight: 28.41

# %%
# Inspect a batch. Each item is (normalised window, scaled features, label):
# the z-scored sequence carries shape, the feature vector carries the level
# and scale that z-scoring necessarily discards.
windows_batch, features_batch, labels_batch = next(iter(train_loader))

print(f"Windows:  {tuple(windows_batch.shape)}")
print(f"Features: {tuple(features_batch.shape)}  ({', '.join(scaler.feature_names)})")
print(f"Labels:   {tuple(labels_batch.shape)}")
print(
    f"In batch: {int(labels_batch.sum())} anomalies, {int((1 - labels_batch).sum())} normal"
)
# Out:
# Windows:  (32, 50)
# Features: (32, 10)  (mean, std, min, max, range, slope, skewness, kurtosis, zero_crossings, autocorr_1)
# Labels:   (32,)
# In batch: 2 anomalies, 30 normal

# %% [markdown]
# ## Summary
#
# We have successfully:
# 1. Loaded NAB time-series data with anomaly labels
# 2. Visualised the data and anomaly regions
# 3. Created sliding windows for model input
# 4. Set up PyTorch DataLoaders with class weighting
#
# Next: See `03_model_training.ipynb` for training the transformer model.
